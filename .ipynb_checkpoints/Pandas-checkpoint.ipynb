# %%
import pandas as pd

# %%
#2 main datatypes
series = pd.Series(["BMW", "Toyota", "Honda"])

# %% [raw]
# series

# %%
colors = pd.Series(["Red", "Blue", "White"])
colors
# Out:
# 0      Red
# 1     Blue
# 2    White
# dtype: object

# %%
#DataFrame = 2 dimensional
car_data = pd.DataFrame({"Car Make": series, "Colors" : colors})
car_data
# Out:
#   Car Make Colors
# 0      BMW    Red
# 1   Toyota   Blue
# 2    Honda  White

# %%
#Import Data

# %%
car_sales = pd.read_csv("car-sales (1).csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
#Exporting DataFrame
car_sales.to_csv("exported-car-sales.csv", index=False)

# %%
export_car_sales = pd.read_csv("exported-car-sales.csv")
export_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Describe data

# %%
# Attritube
car_sales.dtypes

#Function
#car_sales.to_csv()
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns = car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
car_sales.mean(numeric_only=True)
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_prices = pd.Series([3000, 1500, 111250])
car_prices.mean(numeric_only=True)
# Out:
# np.float64(38583.333333333336)

# %%
car_sales.sum
# Out:
# <bound method DataFrame.sum of      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00>

# %%
car_sales["Doors"].sum()
# Out:
# np.int64(40)

# %%
len(car_sales)
# Out:
# 10

# %% [markdown]
# ## Viewing and selecting data

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# .loc & .iloc
animals = pd.Series(["cat", "dog", "bird", "panda", "snake"],
index= [0,3,9,8,3])
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
animals.loc[3]
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
animals.loc[9]
# Out:
# 'bird'

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
# .iloc refers to position
animals.iloc[3]
# Out:
# 'panda'

# %%
# .loc refers to index
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animals.iloc[:3]
# Out:
# 0     cat
# 3     dog
# 9    bird
# dtype: object

# %%
car_sales.loc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales["Colour"]
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
car_sales.Colour
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
car_sales[car_sales["Make"] == "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White      93776.875      4  $4,000.00
# 2  Toyota   Blue      20343.125      3  $7,000.00
# 5  Toyota  Green      62008.125      4  $4,500.00
# 8  Toyota  White      37500.000      4  $6,250.00

# %%
car_sales[car_sales["Odometer (KM)"] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 4  Nissan  White     133184.375      4  $3,500.00

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_sales["Odometer (KM)"].plot()
# Out:
# <Axes: >

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %%
#car_sales["Price"] = car_sales["Price"].astype(str).str.replace(r'[\$\,\.]', '', regex=True)
#print(car_sales["Price"].head())
car_sales["Price"] = car_sales["Price"].astype(str).str.replace('[\\$\\,\\.]', '').astype(int)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats   Fuel per 100 miles  \
# 0  toyota  White   58610.546875      4   400000    5.0                  7.5
# 1   honda    Red   34335.546875      4   500000    5.0                  9.2
# 2  toyota   Blue   12714.453125      3   700000    5.0                  5.0
# 3     bmw  Black    4366.796875      5  2200000    5.0                  9.6
# 4  nissan  White   83240.234375      4   350000    5.0                  8.7
# 5  toyota  Green   38755.078125      4   450000    5.0                  4.7
# 6   honda   Blue   17850.781250      4   750000    5.0                  7.6
# 7   honda   Blue   21382.031250      4   700000    5.0                  8.7
# 8  toyota  White   23437.500000      4   625000    5.0                  3.0
# 9  nissan  White   12343.750000      4   970000    5.0                  4.5
#
#    Total fuel used in (L)  Number of Wheels  Passed road safety     EV
# ...

# %%
car_sales["Price"].plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Manipulating Data

# %%
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales["Make"] = car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White      93776.875      4   400000
# 1   honda    Red      54936.875      4   500000
# 2  toyota   Blue      20343.125      3   700000
# 3     bmw  Black       6986.875      5  2200000
# 4  nissan  White     133184.375      4   350000
# 5  toyota  Green      62008.125      4   450000
# 6   honda   Blue      28561.250      4   750000
# 7   honda   Blue      34211.250      4   700000
# 8  toyota  White      37500.000      4   625000
# 9  nissan  White      19750.000      4   970000

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean)
# Out:
# 0                                             150043.0
# 1                                              87899.0
# 2    <bound method Series.mean of 0    150043.0\n1 ...
# 3                                              11179.0
# 4                                             213095.0
# 5    <bound method Series.mean of 0    150043.0\n1 ...
# 6    <bound method Series.mean of 0    150043.0\n1 ...
# 7    <bound method Series.mean of 0    150043.0\n1 ...
# 8                                              60000.0
# 9                                              31600.0
# Name: Odometer, dtype: object

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
# Column from series
seats_column = pd.Series([5,5,5,5,5,5])

# New Column called seats
car_sales["Seats"] = seats_column

car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White      93776.875      4   400000    5.0
# 1   honda    Red      54936.875      4   500000    5.0
# 2  toyota   Blue      20343.125      3   700000    5.0
# 3     bmw  Black       6986.875      5  2200000    5.0
# 4  nissan  White     133184.375      4   350000    5.0
# 5  toyota  Green      62008.125      4   450000    5.0
# 6   honda   Blue      28561.250      4   750000    NaN
# 7   honda   Blue      34211.250      4   700000    NaN
# 8  toyota  White      37500.000      4   625000    NaN
# 9  nissan  White      19750.000      4   970000    NaN

# %%
car_sales["Seats"].fillna(5, inplace=True)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White      93776.875      4   400000    5.0
# 1   honda    Red      54936.875      4   500000    5.0
# 2  toyota   Blue      20343.125      3   700000    5.0
# 3     bmw  Black       6986.875      5  2200000    5.0
# 4  nissan  White     133184.375      4   350000    5.0
# 5  toyota  Green      62008.125      4   450000    5.0
# 6   honda   Blue      28561.250      4   750000    5.0
# 7   honda   Blue      34211.250      4   700000    5.0
# 8  toyota  White      37500.000      4   625000    5.0
# 9  nissan  White      19750.000      4   970000    5.0

# %%
# Column from Python list
fuel_economy = [7.5, 9.2, 5.0,9.6,8.7,4.7,7.6,8.7,3.0,4.5 ]
car_sales[" Fuel per 100 miles"] = fuel_economy

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats   Fuel per 100 miles
# 0  toyota  White      93776.875      4   400000    5.0                  7.5
# 1   honda    Red      54936.875      4   500000    5.0                  9.2
# 2  toyota   Blue      20343.125      3   700000    5.0                  5.0
# 3     bmw  Black       6986.875      5  2200000    5.0                  9.6
# 4  nissan  White     133184.375      4   350000    5.0                  8.7
# 5  toyota  Green      62008.125      4   450000    5.0                  4.7
# 6   honda   Blue      28561.250      4   750000    5.0                  7.6
# 7   honda   Blue      34211.250      4   700000    5.0                  8.7
# 8  toyota  White      37500.000      4   625000    5.0                  3.0
# 9  nissan  White      19750.000      4   970000    5.0                  4.5

# %%
car_sales["Total fuel used in (L)"] = car_sales["Odometer (KM)"]/100 * car_sales[" Fuel per 100 miles"]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats   Fuel per 100 miles  \
# 0  toyota  White      93776.875      4   400000    5.0                  7.5
# 1   honda    Red      54936.875      4   500000    5.0                  9.2
# 2  toyota   Blue      20343.125      3   700000    5.0                  5.0
# 3     bmw  Black       6986.875      5  2200000    5.0                  9.6
# 4  nissan  White     133184.375      4   350000    5.0                  8.7
# 5  toyota  Green      62008.125      4   450000    5.0                  4.7
# 6   honda   Blue      28561.250      4   750000    5.0                  7.6
# 7   honda   Blue      34211.250      4   700000    5.0                  8.7
# 8  toyota  White      37500.000      4   625000    5.0                  3.0
# 9  nissan  White      19750.000      4   970000    5.0                  4.5
#
#    Total fuel used in (L)
# 0             7033.265625
# 1             5054.192500
# 2             1017.156250
# ...

# %%
# Create a column from a single value
car_sales["Number of Wheels"] = 4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats   Fuel per 100 miles  \
# 0  toyota  White      93776.875      4   400000    5.0                  7.5
# 1   honda    Red      54936.875      4   500000    5.0                  9.2
# 2  toyota   Blue      20343.125      3   700000    5.0                  5.0
# 3     bmw  Black       6986.875      5  2200000    5.0                  9.6
# 4  nissan  White     133184.375      4   350000    5.0                  8.7
# 5  toyota  Green      62008.125      4   450000    5.0                  4.7
# 6   honda   Blue      28561.250      4   750000    5.0                  7.6
# 7   honda   Blue      34211.250      4   700000    5.0                  8.7
# 8  toyota  White      37500.000      4   625000    5.0                  3.0
# 9  nissan  White      19750.000      4   970000    5.0                  4.5
#
#    Total fuel used in (L)  Number of Wheels
# 0             7033.265625                 4
# ...

# %%
car_sales["Passed road safety"] = True
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats   Fuel per 100 miles  \
# 0  toyota  White      93776.875      4   400000    5.0                  7.5
# 1   honda    Red      54936.875      4   500000    5.0                  9.2
# 2  toyota   Blue      20343.125      3   700000    5.0                  5.0
# 3     bmw  Black       6986.875      5  2200000    5.0                  9.6
# 4  nissan  White     133184.375      4   350000    5.0                  8.7
# 5  toyota  Green      62008.125      4   450000    5.0                  4.7
# 6   honda   Blue      28561.250      4   750000    5.0                  7.6
# 7   honda   Blue      34211.250      4   700000    5.0                  8.7
# 8  toyota  White      37500.000      4   625000    5.0                  3.0
# 9  nissan  White      19750.000      4   970000    5.0                  4.5
#
#    Total fuel used in (L)  Number of Wheels  Passed road safety
# 0             7033.265625                 4                True
# ...

# %%
car_sales = car_sales.drop("Total fuel used in (L)", axis=1)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats   Fuel per 100 miles  \
# 0  toyota  White   58610.546875      4   400000    5.0                  7.5
# 1   honda    Red   34335.546875      4   500000    5.0                  9.2
# 2  toyota   Blue   12714.453125      3   700000    5.0                  5.0
# 3     bmw  Black    4366.796875      5  2200000    5.0                  9.6
# 4  nissan  White   83240.234375      4   350000    5.0                  8.7
# 5  toyota  Green   38755.078125      4   450000    5.0                  4.7
# 6   honda   Blue   17850.781250      4   750000    5.0                  7.6
# 7   honda   Blue   21382.031250      4   700000    5.0                  8.7
# 8  toyota  White   23437.500000      4   625000    5.0                  3.0
# 9  nissan  White   12343.750000      4   970000    5.0                  4.5
#
#    Number of Wheels  Passed road safety     EV
# 0                 4                True  False
# ...

# %%
car_sales["EV"] = False
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats   Fuel per 100 miles  \
# 0  toyota  White      93776.875      4   400000    5.0                  7.5
# 1   honda    Red      54936.875      4   500000    5.0                  9.2
# 2  toyota   Blue      20343.125      3   700000    5.0                  5.0
# 3     bmw  Black       6986.875      5  2200000    5.0                  9.6
# 4  nissan  White     133184.375      4   350000    5.0                  8.7
# 5  toyota  Green      62008.125      4   450000    5.0                  4.7
# 6   honda   Blue      28561.250      4   750000    5.0                  7.6
# 7   honda   Blue      34211.250      4   700000    5.0                  8.7
# 8  toyota  White      37500.000      4   625000    5.0                  3.0
# 9  nissan  White      19750.000      4   970000    5.0                  4.5
#
#    Total fuel used in (L)  Number of Wheels  Passed road safety     EV
# ...

# %%
car_sales_shuffled = car_sales.sample(frac=1)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats   Fuel per 100 miles  \
# 7   honda   Blue      34211.250      4   700000    5.0                  8.7
# 8  toyota  White      37500.000      4   625000    5.0                  3.0
# 3     bmw  Black       6986.875      5  2200000    5.0                  9.6
# 9  nissan  White      19750.000      4   970000    5.0                  4.5
# 1   honda    Red      54936.875      4   500000    5.0                  9.2
# 4  nissan  White     133184.375      4   350000    5.0                  8.7
# 5  toyota  Green      62008.125      4   450000    5.0                  4.7
# 0  toyota  White      93776.875      4   400000    5.0                  7.5
# 2  toyota   Blue      20343.125      3   700000    5.0                  5.0
# 6   honda   Blue      28561.250      4   750000    5.0                  7.6
#
#    Total fuel used in (L)  Number of Wheels  Passed road safety     EV
# ...

# %%
# only selet 20% of data
car_sales_shuffled.sample(frac=0.2)
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Seats   Fuel per 100 miles  \
# 2  toyota   Blue      20343.125      3  700000    5.0                  5.0
# 6   honda   Blue      28561.250      4  750000    5.0                  7.6
#
#    Total fuel used in (L)  Number of Wheels  Passed road safety     EV
# 2              1017.15625                 4                True  False
# 6              2170.65500                 4                True  False

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats   Fuel per 100 miles  \
# 0  toyota  White      93776.875      4   400000    5.0                  7.5
# 1   honda    Red      54936.875      4   500000    5.0                  9.2
# 2  toyota   Blue      20343.125      3   700000    5.0                  5.0
# 3     bmw  Black       6986.875      5  2200000    5.0                  9.6
# 4  nissan  White     133184.375      4   350000    5.0                  8.7
# 5  toyota  Green      62008.125      4   450000    5.0                  4.7
# 6   honda   Blue      28561.250      4   750000    5.0                  7.6
# 7   honda   Blue      34211.250      4   700000    5.0                  8.7
# 8  toyota  White      37500.000      4   625000    5.0                  3.0
# 9  nissan  White      19750.000      4   970000    5.0                  4.5
#
#    Total fuel used in (L)  Number of Wheels  Passed road safety     EV
# ...

# %%
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x:x /1.6)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats   Fuel per 100 miles  \
# 0  toyota  White   58610.546875      4   400000    5.0                  7.5
# 1   honda    Red   34335.546875      4   500000    5.0                  9.2
# 2  toyota   Blue   12714.453125      3   700000    5.0                  5.0
# 3     bmw  Black    4366.796875      5  2200000    5.0                  9.6
# 4  nissan  White   83240.234375      4   350000    5.0                  8.7
# 5  toyota  Green   38755.078125      4   450000    5.0                  4.7
# 6   honda   Blue   17850.781250      4   750000    5.0                  7.6
# 7   honda   Blue   21382.031250      4   700000    5.0                  8.7
# 8  toyota  White   23437.500000      4   625000    5.0                  3.0
# 9  nissan  White   12343.750000      4   970000    5.0                  4.5
#
#    Total fuel used in (L)  Number of Wheels  Passed road safety     EV
# ...
